# %% [markdown]
# #INSTALADORES

# %%
# !pip install tensorboard
# !pip install torchinfo
# !pip install --upgrade torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.22.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# #GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
! cp "/content/drive/MyDrive/Colab Notebooks/MLP/data.csv" /content
! cp "/content/drive/MyDrive/Colab Notebooks/MLP/img.zip" /content
! unzip -q img.zip
! rm img.zip
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/MLP/img.zip': No such file or directory
# unzip:  cannot find or open img.zip, img.zip.zip or img.zip.ZIP.
# rm: cannot remove 'img.zip': No such file or directory

# %% [markdown]
# #Weights and Biases INICIALIZACION

# %%
# !pip install wandb
# !wandb login

FALTA GENERAR EL PROYECTO MLP-Obligatorio  Y  OBTENER CLAVE

import wandb
from wandb.keras import WandbCallback

# %% [markdown]
# #FUNCIONES BASE ENTRENO

# %%
import time
import datetime
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from fastprogress import master_bar, progress_bar
from torch.utils.tensorboard import SummaryWriter
import torchinfo
import numpy as np
import random
import pandas as pd
import csv
from PIL import Image

from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data.dataloader import DataLoader

from sklearn.metrics import accuracy_score, confusion_matrix

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def to_oneHot(label, numberOfClass):
  oneHot_label = torch.zeros(label.shape[0],numberOfClass).to(device)
  for i in range(label.shape[0]):
    oneHot_label[i][label[i]]=1
  return oneHot_label

def train_step(mlp_model, criterion, optim, img,tabulars, label, batch_size, numberOfClass):
    optim.zero_grad()
    output = mlp_model(input, tabulars)
    loss = criterion(output, label)
    loss.backward()
    optim.step()
    step_loss = loss.item()
    return step_loss

def train_epoch(mlp_model, loader, criterion, optim,mb,numberOfClass):
    epoch_loss_accumulated = 0.0
    for img, tabulars, label in  progress_bar(loader,parent = mb):
      batch_size = img.size(0)
      epoch_loss_accumulated += train_step(mlp_model,criterion,optim, img, tabulars, label, batch_size,numberOfClass)
    return epoch_loss_accumulated/len(loader)

# %%
def validation_epoch(mlp_model, val_loader, criterion, classes = None):
    mlp_model.eval()
    epoch_loss = 0.0
    all_labels = []
    all_predictions = []
    
    with torch.no_grad():
      for images, tabulars, label in val_loader:
        all_labels.extend(labels.numpy())  
        labels = labels.to(device)
        labels = to_oneHot(label,classes)
        predictions = mlp_model(images.to(device), tabulars)
        all_predictions.extend(torch.argmax(predictions, dim=1).cpu().numpy())

        loss = criterion(predictions, labels)

        epoch_loss += loss.item()    

    return epoch_loss / len(val_loader), accuracy_score(all_labels, all_predictions) * 100

# %%
def train_model(mlp_model, train_loader, valid_loader, criterion, optim, number_epochs,numberOfClass):
  train_history = []
  valid_history = []
  accuracy_history = []
  now = datetime.datetime.now()
  date_time = now.strftime("%m%d%Y_%H%M%S")
  name = 'runs/'+mlp_model.name+'_'+date_time
  tensorBoard_writer = SummaryWriter(name) 
  mb = master_bar(range(1, number_epochs+1))
  for epoch in mb:
      start_time = time.time()     
      train_loss = train_epoch(mlp_model, train_loader, criterion, optim,mb,numberOfClass)
      train_history.append(train_loss)
      print("Training epoch {} | Loss {:.6f} | Time {:.2f} seconds"
            .format(epoch + 1, train_loss, time.time() - start_time))
      
      start_time = time.time()
      val_loss, acc = validation_epoch(mlp_model, valid_loader, criterion)
      valid_history.append(val_loss)
      accuracy_history.append(acc)
      print("Validation epoch {} | Loss {:.6f} | Accuracy {:.2f}% | Time {:.2f} seconds"
            .format(epoch + 1, val_loss, acc, time.time() - start_time))
      # Se carga en tensorBoard #Loss #Validation en train y val
      tensorBoard_writer.add_scalar(tag="Train Loss", scalar_value=train_loss, global_step=epoch)
      tensorBoard_writer.add_scalar(tag="Validation Loss", scalar_value=val_loss, global_step=epoch)
      tensorBoard_writer.add_scalar(tag="Validation Accuracy", scalar_value=acc, global_step=epoch)
  tensorBoard_writer.close()

# %% [markdown]
# #CARGA DE DATOS

# %%
def load_data():  
  data = []
  with open("./data.csv", 'r') as file:
    lector_csv = csv.reader(file)
    next(lector_csv)
    for fila in lector_csv:
      fila_enteros = [int(float(valor)) for valor in fila]
      data.append(fila_enteros)

  data = np.array(data)
  nombres_imagenes = data[:, 0]

  datos_con_imagenes = []

  for nombre_imagen, fila_datos in zip(nombres_imagenes, data):
      imagen = 0
      try:
        imagen = Image.open("./img/" + str(nombre_imagen)+ ".jpeg")
      except FileNotFoundError:
        print("Error: El archivo de imagen " + str(nombre_imagen)+ ".jpeg no existe.")
      label = 0
      if fila_datos[6] > 100000 and fila_datos[6] <= 200000:
        label = 1
      elif fila_datos[6] > 200000 and fila_datos[6] <= 300000:
        label = 2
      elif fila_datos[6] > 300000:
        label = 3
      datos_con_imagenes.append((np.array(imagen), fila_datos[1:6], label))
  print(len(datos_con_imagenes))
  return datos_con_imagenes

# %%
def get_dataloaders(train_transf,batch_size):
# Vector de vectores img, tabulares, label -------------------------------------------------------------------------------------------------------------------------------------
  train_dataset = load_data()
# Vector de vectores img, tabulares, label -------------------------------------------------------------------------------------------------------------------------------------

  BATCH_SIZE = batch_size

  # Separamos en train y validation
  train_size = int(0.8 * len(train_dataset))
  valid_size = len(train_dataset) - train_size

  train, validation = torch.utils.data.random_split(train_dataset, [train_size,valid_size])

  print(f"{len(train)} Training Items, {len(validation)} Validation Items")

  # Podemos usar data loaders como vimos en el práctico.
  train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=True,pin_memory=True)
  valid_loader = DataLoader(validation, batch_size=BATCH_SIZE, pin_memory=True)
  
  return train_loader, valid_loader

# %% [markdown]
# #MODELO

# %%
# %load_ext tensorboard

# %%
class MLP_Model(nn.Module):
  def __init__(self,name="MLP_MODEL", vocab_size=260, embedding_dim=4, num_classes=4):
    super().__init__()
    self.name = name
    self.embedding = nn.Embedding(num_embeddings=vocab_size,embedding_dim=embedding_dim)
    self.conv1 = nn.Conv2d(3, 64, 4, stride=2, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.conv2 = nn.Conv2d(64, 128, 4, stride=2, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(128)
    self.conv3 = nn.Conv2d(128, 256, 4, stride=2, padding=1, bias=False)
    self.bn3 = nn.BatchNorm2d(256)
    self.conv4 = nn.Conv2d(256, 64, 4, stride=2, padding=1, bias=False)
    self.bn4 = nn.BatchNorm2d(64)
    self.linear1 = nn.Linear(64*16*12+5+(embedding_dim-1), 1024)
    self.linear2 = nn.Linear(1024, 512)
    self.linear3 = nn.Linear(512, 128)
    self.linear4 = nn.Linear(128, 64)
    self.out = nn.Linear(64, num_classes)


  def forward(self, x,tabulars):
    # entrada de 256*192
    emb_Location = self.embedding(tabulars[4])
    x = x.view(x.size(0), 3, 256, 192)
    x = F.relu(self.bn1(self.conv1(x)))
    x = F.relu(self.bn2(self.conv2(x)))
    x = F.relu(self.bn3(self.conv3(x)))
    x = F.relu(self.bn4(self.conv4(x)))
    x = x.view(x.size(0), -1)
    x = torch.concat([x, emb_Location, tabulars[1:]],-1)
    x = F.relu(self.linear1(x))
    x = F.relu(self.linear2(x))
    x = F.relu(self.linear3(x))
    x = F.relu(self.linear4(x))
    return x

# %%
torchinfo.summary(MLP_Model())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP_Model                                --
# ├─Embedding: 1-1                         1,040
# ├─Conv2d: 1-2                            3,072
# ├─BatchNorm2d: 1-3                       128
# ├─Conv2d: 1-4                            131,072
# ├─BatchNorm2d: 1-5                       256
# ├─Conv2d: 1-6                            524,288
# ├─BatchNorm2d: 1-7                       512
# ├─Conv2d: 1-8                            262,144
# ├─BatchNorm2d: 1-9                       128
# ├─Linear: 1-10                           12,592,128
# ├─Linear: 1-11                           524,800
# ├─Linear: 1-12                           65,664
# ├─Linear: 1-13                           8,256
# ├─Linear: 1-14                           260
# =================================================================
# Total params: 14,113,748
# Trainable params: 14,113,748
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# #PARAMETROS

# %%
config = wandb.config # Config is a variable that holds and saves hyperparameters and inputs

config.LR = 2e-4
config.epochs = 50
config.batch_size = 32
config.B = [0.5,0.999]
config.info = 'Modelo MLP'

# %%
# Creamos los dataloaders
train_transform = transforms.Compose([
    transforms.Resize([256,192]),
    transforms.ToTensor()
])

# Creamos el loaders
train_loader, val_loader = get_dataloaders(train_transform,batch_size=32)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Error: El archivo de imagen 39843.jpeg no existe.
# Error: El archivo de imagen 39845.jpeg no existe.
# Error: El archivo de imagen 39850.jpeg no existe.
# Error: El archivo de imagen 39851.jpeg no existe.
# Error: El archivo de imagen 39854.jpeg no existe.
# Error: El archivo de imagen 39855.jpeg no existe.
# Error: El archivo de imagen 39856.jpeg no existe.
# Error: El archivo de imagen 39861.jpeg no existe.
# Error: El archivo de imagen 39864.jpeg no existe.
# Error: El archivo de imagen 39863.jpeg no existe.
# Error: El archivo de imagen 39865.jpeg no existe.
# Error: El archivo de imagen 39866.jpeg no existe.
# Error: El archivo de imagen 39869.jpeg no existe.
# Error: El archivo de imagen 39867.jpeg no existe.
# Error: El archivo de imagen 39871.jpeg no existe.
# Error: El archivo de imagen 39872.jpeg no existe.
# Error: El archivo de imagen 39875.jpeg no existe.
# Error: El archivo de imagen 39876.jpeg no existe.
# Error: El archivo de imagen 39878.jpeg no existe.
# Error: El archivo de imagen 39880.jpeg no existe.
# Error: El archivo de imagen 39884.jpeg no existe.
# Error: El archivo de imagen 39886.jpeg no existe.
# Error: El archivo de imagen 39888.jpeg no existe.
# Error: El archivo de imagen 39887.jpeg no existe.
# Error: El archivo de imagen 39889.jpeg no existe.
# Error: El archivo de imagen 39892.jpeg no existe.
# Error: El archivo de imagen 39894.jpeg no existe.
# Error: El archivo de imagen 39896.jpeg no existe.
# Error: El archivo de imagen 39897.jpeg no existe.
# Error: El archivo de imagen 39899.jpeg no existe.
# Error: El archivo de imagen 39902.jpeg no existe.
# Error: El archivo de imagen 39903.jpeg no existe.
# Error: El archivo de imagen 39904.jpeg no existe.
# Error: El archivo de imagen 39909.jpeg no existe.
# Error: El archivo de imagen 39911.jpeg no existe.
# Error: El archivo de imagen 39912.jpeg no existe.
# Error: El archivo de imagen 39917.jpeg no existe.
# Error: El archivo de imagen 39919.jpeg no existe.
# Error: El archivo de imagen 39921.jpeg no existe.
# Error: El archivo de imagen 39924.jpeg no existe.
# Error: El archivo de imagen 39923.jpeg no existe.
# Error: El archivo de imagen 39927.jpeg no existe.
# Error: El archivo de imagen 39925.jpeg no existe.
# Error: El archivo de imagen 39926.jpeg no existe.
# Error: El archivo de imagen 39929.jpeg no existe.
# Error: El archivo de imagen 39930.jpeg no existe.
# Error: El archivo de imagen 39931.jpeg no existe.
# Error: El archivo de imagen 39932.jpeg no existe.
# Error: El archivo de imagen 39934.jpeg no existe.
# Error: El archivo de imagen 39935.jpeg no existe.
# Error: El archivo de imagen 39939.jpeg no existe.
# Error: El archivo de imagen 39941.jpeg no existe.
# Error: El archivo de imagen 39940.jpeg no existe.
# Error: El archivo de imagen 39944.jpeg no existe.
# Error: El archivo de imagen 39942.jpeg no existe.
# Error: El archivo de imagen 39945.jpeg no existe.
# Error: El archivo de imagen 39943.jpeg no existe.
# Error: El archivo de imagen 39949.jpeg no existe.
# Error: El archivo de imagen 39951.jpeg no existe.
# Error: El archivo de imagen 39952.jpeg no existe.
# Error: El archivo de imagen 39955.jpeg no existe.
# Error: El archivo de imagen 39956.jpeg no existe.
# Error: El archivo de imagen 39958.jpeg no existe.
# Error: El archivo de imagen 39963.jpeg no existe.
# Error: El archivo de imagen 39962.jpeg no existe.
# Error: El archivo de imagen 39964.jpeg no existe.
# Error: El archivo de imagen 39965.jpeg no existe.
# Error: El archivo de imagen 39966.jpeg no existe.
# Error: El archivo de imagen 39967.jpeg no existe.
# Error: El archivo de imagen 39969.jpeg no existe.
# Error: El archivo de imagen 39970.jpeg no existe.
# Error: El archivo de imagen 39972.jpeg no existe.
# Error: El archivo de imagen 39974.jpeg no existe.
# Error: El archivo de imagen 39977.jpeg no existe.
# Error: El archivo de imagen 39976.jpeg no existe.
# Error: El archivo de imagen 39978.jpeg no existe.
# Error: El archivo de imagen 39982.jpeg no existe.
# Error: El archivo de imagen 39980.jpeg no existe.
# Error: El archivo de imagen 39984.jpeg no existe.
# Error: El archivo de imagen 39983.jpeg no existe.
# Error: El archivo de imagen 39975.jpeg no existe.
# Error: El archivo de imagen 39987.jpeg no existe.
# Error: El archivo de imagen 39988.jpeg no existe.
# Error: El archivo de imagen 39989.jpeg no existe.
# Error: El archivo de imagen 39991.jpeg no existe.
# Error: El archivo de imagen 39994.jpeg no existe.
# Error: El archivo de imagen 39996.jpeg no existe.
# Error: El archivo de imagen 39993.jpeg no existe.
# Error: El archivo de imagen 39997.jpeg no existe.
# Error: El archivo de imagen 39998.jpeg no existe.
# Error: El archivo de imagen 39999.jpeg no existe.
# Error: El archivo de imagen 40000.jpeg no existe.
# Error: El archivo de imagen 40002.jpeg no existe.
# Error: El archivo de imagen 40003.jpeg no existe.
# Error: El archivo de imagen 40006.jpeg no existe.
# Error: El archivo de imagen 40009.jpeg no existe.
# Error: El archivo de imagen 40010.jpeg no existe.
# Error: El archivo de imagen 40013.jpeg no existe.
# Error: El archivo de imagen 40014.jpeg no existe.
# Error: El archivo de imagen 40017.jpeg no existe.
# Error: El archivo de imagen 40020.jpeg no existe.
# Error: El archivo de imagen 40019.jpeg no existe.
# Error: El archivo de imagen 40024.jpeg no existe.
# Error: El archivo de imagen 40027.jpeg no existe.
# Error: El archivo de imagen 40028.jpeg no existe.
# Error: El archivo de imagen 40030.jpeg no existe.
# Error: El archivo de imagen 40031.jpeg no existe.
# Error: El archivo de imagen 40032.jpeg no existe.
# Error: El archivo de imagen 40035.jpeg no existe.
# Error: El archivo de imagen 40039.jpeg no existe.
# Error: El archivo de imagen 40040.jpeg no existe.
# Error: El archivo de imagen 40041.jpeg no existe.
# Error: El archivo de imagen 40044.jpeg no existe.
# Error: El archivo de imagen 40050.jpeg no existe.
# Error: El archivo de imagen 40052.jpeg no existe.
# Error: El archivo de imagen 40057.jpeg no existe.
# Error: El archivo de imagen 40059.jpeg no existe.
# Error: El archivo de imagen 40060.jpeg no existe.
# Error: El archivo de imagen 40062.jpeg no existe.
# Error: El archivo de imagen 40063.jpeg no existe.
# Error: El archivo de imagen 40069.jpeg no existe.
# Error: El archivo de imagen 40071.jpeg no existe.
# Error: El archivo de imagen 40072.jpeg no existe.
# Error: El archivo de imagen 40077.jpeg no existe.
# Error: El archivo de imagen 40074.jpeg no existe.
# Error: El archivo de imagen 40073.jpeg no existe.
# Error: El archivo de imagen 40078.jpeg no existe.
# Error: El archivo de imagen 40079.jpeg no existe.
# Error: El archivo de imagen 40082.jpeg no existe.
# Error: El archivo de imagen 40083.jpeg no existe.
# Error: El archivo de imagen 40084.jpeg no existe.
# Error: El archivo de imagen 40085.jpeg no existe.
# Error: El archivo de imagen 40087.jpeg no existe.
# Error: El archivo de imagen 40088.jpeg no existe.
# Error: El archivo de imagen 40089.jpeg no existe.
# Error: El archivo de imagen 40092.jpeg no existe.
# Error: El archivo de imagen 40094.jpeg no existe.
# Error: El archivo de imagen 40097.jpeg no existe.
# Error: El archivo de imagen 40099.jpeg no existe.
# Error: El archivo de imagen 40098.jpeg no existe.
# Error: El archivo de imagen 40106.jpeg no existe.
# Error: El archivo de imagen 40109.jpeg no existe.
# Error: El archivo de imagen 40111.jpeg no existe.
# Error: El archivo de imagen 40113.jpeg no existe.
# Error: El archivo de imagen 40115.jpeg no existe.
# Error: El archivo de imagen 40120.jpeg no existe.
# Error: El archivo de imagen 40118.jpeg no existe.
# Error: El archivo de imagen 40119.jpeg no existe.
# Error: El archivo de imagen 40125.jpeg no existe.
# Error: El archivo de imagen 40135.jpeg no existe.
# Error: El archivo de imagen 40139.jpeg no existe.
# Error: El archivo de imagen 40141.jpeg no existe.
# Error: El archivo de imagen 40142.jpeg no existe.
# Error: El archivo de imagen 40146.jpeg no existe.
# Error: El archivo de imagen 40147.jpeg no existe.
# Error: El archivo de imagen 40148.jpeg no existe.
# Error: El archivo de imagen 40150.jpeg no existe.
# Error: El archivo de imagen 40151.jpeg no existe.
# Error: El archivo de imagen 40152.jpeg no existe.
# Error: El archivo de imagen 40154.jpeg no existe.
# Error: El archivo de imagen 40153.jpeg no existe.
# Error: El archivo de imagen 40155.jpeg no existe.
# Error: El archivo de imagen 40159.jpeg no existe.
# Error: El archivo de imagen 40161.jpeg no existe.
# Error: El archivo de imagen 40160.jpeg no existe.
# Error: El archivo de imagen 40162.jpeg no existe.
# Error: El archivo de imagen 40163.jpeg no existe.
# Error: El archivo de imagen 40166.jpeg no existe.
# Error: El archivo de imagen 40167.jpeg no existe.
# Error: El archivo de imagen 40168.jpeg no existe.
# Error: El archivo de imagen 40173.jpeg no existe.
# Error: El archivo de imagen 40174.jpeg no existe.
# Error: El archivo de imagen 40175.jpeg no existe.
# Error: El archivo de imagen 40177.jpeg no existe.
# Error: El archivo de imagen 40182.jpeg no existe.
# Error: El archivo de imagen 40183.jpeg no existe.
# Error: El archivo de imagen 40190.jpeg no existe.
# Error: El archivo de imagen 40188.jpeg no existe.
# Error: El archivo de imagen 40187.jpeg no existe.
# Error: El archivo de imagen 40191.jpeg no existe.
# Error: El archivo de imagen 40192.jpeg no existe.
# Error: El archivo de imagen 40194.jpeg no existe.
# Error: El archivo de imagen 40195.jpeg no existe.
# Error: El archivo de imagen 40196.jpeg no existe.
# Error: El archivo de imagen 40203.jpeg no existe.
# Error: El archivo de imagen 40206.jpeg no existe.
# Error: El archivo de imagen 40209.jpeg no existe.
# Error: El archivo de imagen 40213.jpeg no existe.
# Error: El archivo de imagen 40214.jpeg no existe.
# Error: El archivo de imagen 40215.jpeg no existe.
# Error: El archivo de imagen 40217.jpeg no existe.
# Error: El archivo de imagen 40216.jpeg no existe.
# Error: El archivo de imagen 40219.jpeg no existe.
# Error: El archivo de imagen 40222.jpeg no existe.
# Error: El archivo de imagen 40225.jpeg no existe.
# Error: El archivo de imagen 40230.jpeg no existe.
# Error: El archivo de imagen 40231.jpeg no existe.
# Error: El archivo de imagen 40232.jpeg no existe.
# Error: El archivo de imagen 40234.jpeg no existe.
# Error: El archivo de imagen 40236.jpeg no existe.
# Error: El archivo de imagen 40237.jpeg no existe.
# Error: El archivo de imagen 40241.jpeg no existe.
# Error: El archivo de imagen 40240.jpeg no existe.
# Error: El archivo de imagen 40245.jpeg no existe.
# Error: El archivo de imagen 40247.jpeg no existe.
# Error: El archivo de imagen 40246.jpeg no existe.
# Error: El archivo de imagen 40249.jpeg no existe.
# Error: El archivo de imagen 40251.jpeg no existe.
# Error: El archivo de imagen 40252.jpeg no existe.
# Error: El archivo de imagen 40254.jpeg no existe.
# Error: El archivo de imagen 40255.jpeg no existe.
# Error: El archivo de imagen 40262.jpeg no existe.
# Error: El archivo de imagen 40258.jpeg no existe.
# Error: El archivo de imagen 40261.jpeg no existe.
# Error: El archivo de imagen 40263.jpeg no existe.
# Error: El archivo de imagen 40265.jpeg no existe.
# Error: El archivo de imagen 40264.jpeg no existe.
# Error: El archivo de imagen 40268.jpeg no existe.
# Error: El archivo de imagen 40275.jpeg no existe.
# Error: El archivo de imagen 40277.jpeg no existe.
# Error: El archivo de imagen 40279.jpeg no existe.
# Error: El archivo de imagen 40283.jpeg no existe.
# Error: El archivo de imagen 40284.jpeg no existe.
# Error: El archivo de imagen 40285.jpeg no existe.
# Error: El archivo de imagen 40286.jpeg no existe.
# Error: El archivo de imagen 40288.jpeg no existe.
# Error: El archivo de imagen 40292.jpeg no existe.
# Error: El archivo de imagen 40293.jpeg no existe.
# Error: El archivo de imagen 40295.jpeg no existe.
# Error: El archivo de imagen 40296.jpeg no existe.
# Error: El archivo de imagen 40299.jpeg no existe.
# Error: El archivo de imagen 40303.jpeg no existe.
# Error: El archivo de imagen 40304.jpeg no existe.
# Error: El archivo de imagen 40307.jpeg no existe.
# Error: El archivo de imagen 40306.jpeg no existe.
# Error: El archivo de imagen 40310.jpeg no existe.
# Error: El archivo de imagen 40311.jpeg no existe.
# Error: El archivo de imagen 40313.jpeg no existe.
# Error: El archivo de imagen 40315.jpeg no existe.
# Error: El archivo de imagen 40316.jpeg no existe.
# Error: El archivo de imagen 40317.jpeg no existe.
# Error: El archivo de imagen 40318.jpeg no existe.
# Error: El archivo de imagen 40320.jpeg no existe.
# Error: El archivo de imagen 40321.jpeg no existe.
# Error: El archivo de imagen 40322.jpeg no existe.
# Error: El archivo de imagen 40324.jpeg no existe.
# Error: El archivo de imagen 40326.jpeg no existe.
# Error: El archivo de imagen 40327.jpeg no existe.
# Error: El archivo de imagen 40329.jpeg no existe.
# Error: El archivo de imagen 40330.jpeg no existe.
# Error: El archivo de imagen 40333.jpeg no existe.
# Error: El archivo de imagen 40339.jpeg no existe.
# Error: El archivo de imagen 40340.jpeg no existe.
# Error: El archivo de imagen 40343.jpeg no existe.
# Error: El archivo de imagen 40346.jpeg no existe.
# Error: El archivo de imagen 40347.jpeg no existe.
# Error: El archivo de imagen 40348.jpeg no existe.
# Error: El archivo de imagen 40350.jpeg no existe.
# Error: El archivo de imagen 40351.jpeg no existe.
# Error: El archivo de imagen 40352.jpeg no existe.
# Error: El archivo de imagen 40353.jpeg no existe.
# Error: El archivo de imagen 40357.jpeg no existe.
# Error: El archivo de imagen 40356.jpeg no existe.
# Error: El archivo de imagen 40358.jpeg no existe.
# Error: El archivo de imagen 40359.jpeg no existe.
# Error: El archivo de imagen 40360.jpeg no existe.
# Error: El archivo de imagen 40362.jpeg no existe.
# Error: El archivo de imagen 40364.jpeg no existe.
# Error: El archivo de imagen 40365.jpeg no existe.
# Error: El archivo de imagen 40366.jpeg no existe.
# Error: El archivo de imagen 40375.jpeg no existe.
# Error: El archivo de imagen 40373.jpeg no existe.
# Error: El archivo de imagen 40376.jpeg no existe.
# Error: El archivo de imagen 40385.jpeg no existe.
# Error: El archivo de imagen 40387.jpeg no existe.
# Error: El archivo de imagen 40386.jpeg no existe.
# Error: El archivo de imagen 40389.jpeg no existe.
# Error: El archivo de imagen 40390.jpeg no existe.
# Error: El archivo de imagen 40394.jpeg no existe.
# Error: El archivo de imagen 40393.jpeg no existe.
# Error: El archivo de imagen 40395.jpeg no existe.
# Error: El archivo de imagen 40396.jpeg no existe.
# Error: El archivo de imagen 40398.jpeg no existe.
# Error: El archivo de imagen 40399.jpeg no existe.
# Error: El archivo de imagen 40400.jpeg no existe.
# Error: El archivo de imagen 40401.jpeg no existe.
# Error: El archivo de imagen 40407.jpeg no existe.
# Error: El archivo de imagen 40410.jpeg no existe.
# Error: El archivo de imagen 40409.jpeg no existe.
# Error: El archivo de imagen 40412.jpeg no existe.
# Error: El archivo de imagen 40413.jpeg no existe.
# Error: El archivo de imagen 40415.jpeg no existe.
# Error: El archivo de imagen 40417.jpeg no existe.
# Error: El archivo de imagen 40421.jpeg no existe.
# Error: El archivo de imagen 40423.jpeg no existe.
# Error: El archivo de imagen 40424.jpeg no existe.
# Error: El archivo de imagen 40431.jpeg no existe.
# Error: El archivo de imagen 40426.jpeg no existe.
# Error: El archivo de imagen 40429.jpeg no existe.
# Error: El archivo de imagen 40428.jpeg no existe.
# Error: El archivo de imagen 40432.jpeg no existe.
# Error: El archivo de imagen 40433.jpeg no existe.
# Error: El archivo de imagen 40435.jpeg no existe.
# Error: El archivo de imagen 40436.jpeg no existe.
# Error: El archivo de imagen 40440.jpeg no existe.
# Error: El archivo de imagen 40448.jpeg no existe.
# Error: El archivo de imagen 40449.jpeg no existe.
# Error: El archivo de imagen 40451.jpeg no existe.
# Error: El archivo de imagen 40454.jpeg no existe.
# Error: El archivo de imagen 40455.jpeg no existe.
# Error: El archivo de imagen 40461.jpeg no existe.
# Error: El archivo de imagen 40462.jpeg no existe.
# Error: El archivo de imagen 40465.jpeg no existe.
# Error: El archivo de imagen 40467.jpeg no existe.
# Error: El archivo de imagen 40469.jpeg no existe.
# Error: El archivo de imagen 40474.jpeg no existe.
# Error: El archivo de imagen 40476.jpeg no existe.
# Error: El archivo de imagen 40477.jpeg no existe.
# Error: El archivo de imagen 40484.jpeg no existe.
# Error: El archivo de imagen 40486.jpeg no existe.
# Error: El archivo de imagen 40479.jpeg no existe.
# Error: El archivo de imagen 40482.jpeg no existe.
# Error: El archivo de imagen 40480.jpeg no existe.
# Error: El archivo de imagen 40485.jpeg no existe.
# Error: El archivo de imagen 40487.jpeg no existe.
# Error: El archivo de imagen 40489.jpeg no existe.
# Error: El archivo de imagen 40492.jpeg no existe.
# Error: El archivo de imagen 40494.jpeg no existe.
# Error: El archivo de imagen 40495.jpeg no existe.
# Error: El archivo de imagen 40497.jpeg no existe.
# Error: El archivo de imagen 40502.jpeg no existe.
# Error: El archivo de imagen 40503.jpeg no existe.
# Error: El archivo de imagen 40504.jpeg no existe.
# Error: El archivo de imagen 40508.jpeg no existe.
# Error: El archivo de imagen 40510.jpeg no existe.
# Error: El archivo de imagen 40513.jpeg no existe.
# Error: El archivo de imagen 40516.jpeg no existe.
# Error: El archivo de imagen 40518.jpeg no existe.
# Error: El archivo de imagen 40522.jpeg no existe.
# Error: El archivo de imagen 40520.jpeg no existe.
# Error: El archivo de imagen 40523.jpeg no existe.
# Error: El archivo de imagen 40532.jpeg no existe.
# Error: El archivo de imagen 40533.jpeg no existe.
# Error: El archivo de imagen 40534.jpeg no existe.
# Error: El archivo de imagen 40536.jpeg no existe.
# Error: El archivo de imagen 40537.jpeg no existe.
# Error: El archivo de imagen 40539.jpeg no existe.
# Error: El archivo de imagen 40542.jpeg no existe.
# Error: El archivo de imagen 40545.jpeg no existe.
# Error: El archivo de imagen 40546.jpeg no existe.
# Error: El archivo de imagen 40544.jpeg no existe.
# Error: El archivo de imagen 40547.jpeg no existe.
# Error: El archivo de imagen 40553.jpeg no existe.
# Error: El archivo de imagen 40551.jpeg no existe.
# Error: El archivo de imagen 40556.jpeg no existe.
# Error: El archivo de imagen 40559.jpeg no existe.
# Error: El archivo de imagen 40560.jpeg no existe.
# Error: El archivo de imagen 40561.jpeg no existe.
# Error: El archivo de imagen 40564.jpeg no existe.
# Error: El archivo de imagen 40568.jpeg no existe.
# Error: El archivo de imagen 40569.jpeg no existe.
# Error: El archivo de imagen 40570.jpeg no existe.
# Error: El archivo de imagen 40571.jpeg no existe.
# Error: El archivo de imagen 40573.jpeg no existe.
# Error: El archivo de imagen 40572.jpeg no existe.
# Error: El archivo de imagen 40575.jpeg no existe.
# Error: El archivo de imagen 40577.jpeg no existe.
# Error: El archivo de imagen 40582.jpeg no existe.
# Error: El archivo de imagen 40579.jpeg no existe.
# Error: El archivo de imagen 40581.jpeg no existe.
# Error: El archivo de imagen 40583.jpeg no existe.
# Error: El archivo de imagen 40586.jpeg no existe.
# Error: El archivo de imagen 40585.jpeg no existe.
# Error: El archivo de imagen 40587.jpeg no existe.
# Error: El archivo de imagen 40590.jpeg no existe.
# Error: El archivo de imagen 40594.jpeg no existe.
# Error: El archivo de imagen 40602.jpeg no existe.
# Error: El archivo de imagen 40603.jpeg no existe.
# Error: El archivo de imagen 40605.jpeg no existe.
# Error: El archivo de imagen 40609.jpeg no existe.
# Error: El archivo de imagen 40611.jpeg no existe.
# Error: El archivo de imagen 40612.jpeg no existe.
# Error: El archivo de imagen 40614.jpeg no existe.
# Error: El archivo de imagen 40613.jpeg no existe.
# Error: El archivo de imagen 40615.jpeg no existe.
# Error: El archivo de imagen 40616.jpeg no existe.
# Error: El archivo de imagen 40618.jpeg no existe.
# Error: El archivo de imagen 40617.jpeg no existe.
# Error: El archivo de imagen 40619.jpeg no existe.
# Error: El archivo de imagen 40622.jpeg no existe.
# Error: El archivo de imagen 40630.jpeg no existe.
# Error: El archivo de imagen 40627.jpeg no existe.
# Error: El archivo de imagen 40629.jpeg no existe.
# Error: El archivo de imagen 40631.jpeg no existe.
# Error: El archivo de imagen 40632.jpeg no existe.
# Error: El archivo de imagen 40634.jpeg no existe.
# Error: El archivo de imagen 40635.jpeg no existe.
# Error: El archivo de imagen 40637.jpeg no existe.
# Error: El archivo de imagen 40638.jpeg no existe.
# Error: El archivo de imagen 40640.jpeg no existe.
# Error: El archivo de imagen 40641.jpeg no existe.
# Error: El archivo de imagen 40643.jpeg no existe.
# Error: El archivo de imagen 40645.jpeg no existe.
# Error: El archivo de imagen 40649.jpeg no existe.
# Error: El archivo de imagen 40650.jpeg no existe.
# Error: El archivo de imagen 40651.jpeg no existe.
# Error: El archivo de imagen 40652.jpeg no existe.
# Error: El archivo de imagen 40653.jpeg no existe.
# Error: El archivo de imagen 40656.jpeg no existe.
# Error: El archivo de imagen 40655.jpeg no existe.
# Error: El archivo de imagen 40658.jpeg no existe.
# Error: El archivo de imagen 40663.jpeg no existe.
# Error: El archivo de imagen 40664.jpeg no existe.
# Error: El archivo de imagen 40665.jpeg no existe.
# Error: El archivo de imagen 40668.jpeg no existe.
# Error: El archivo de imagen 40666.jpeg no existe.
# Error: El archivo de imagen 40667.jpeg no existe.
# Error: El archivo de imagen 40671.jpeg no existe.
# Error: El archivo de imagen 40674.jpeg no existe.
# Error: El archivo de imagen 40673.jpeg no existe.
# Error: El archivo de imagen 40676.jpeg no existe.
# Error: El archivo de imagen 40677.jpeg no existe.
# Error: El archivo de imagen 40679.jpeg no existe.
# Error: El archivo de imagen 40681.jpeg no existe.
# Error: El archivo de imagen 40685.jpeg no existe.
# Error: El archivo de imagen 40683.jpeg no existe.
# Error: El archivo de imagen 40689.jpeg no existe.
# Error: El archivo de imagen 40688.jpeg no existe.
# Error: El archivo de imagen 40690.jpeg no existe.
# Error: El archivo de imagen 40691.jpeg no existe.
# Error: El archivo de imagen 40692.jpeg no existe.
# Error: El archivo de imagen 40693.jpeg no existe.
# Error: El archivo de imagen 40695.jpeg no existe.
# Error: El archivo de imagen 40698.jpeg no existe.
# Error: El archivo de imagen 40697.jpeg no existe.
# Error: El archivo de imagen 40699.jpeg no existe.
# Error: El archivo de imagen 40703.jpeg no existe.
# Error: El archivo de imagen 40705.jpeg no existe.
# Error: El archivo de imagen 40706.jpeg no existe.
# Error: El archivo de imagen 40709.jpeg no existe.
# Error: El archivo de imagen 40707.jpeg no existe.
# Error: El archivo de imagen 40708.jpeg no existe.
# Error: El archivo de imagen 40710.jpeg no existe.
# Error: El archivo de imagen 40711.jpeg no existe.
# Error: El archivo de imagen 40712.jpeg no existe.
# Error: El archivo de imagen 40713.jpeg no existe.
# Error: El archivo de imagen 40715.jpeg no existe.
# Error: El archivo de imagen 40718.jpeg no existe.
# Error: El archivo de imagen 40719.jpeg no existe.
# Error: El archivo de imagen 40721.jpeg no existe.
# Error: El archivo de imagen 40720.jpeg no existe.
# Error: El archivo de imagen 40722.jpeg no existe.
# Error: El archivo de imagen 40725.jpeg no existe.
# Error: El archivo de imagen 40727.jpeg no existe.
# Error: El archivo de imagen 40726.jpeg no existe.
# Error: El archivo de imagen 40728.jpeg no existe.
# Error: El archivo de imagen 40729.jpeg no existe.
# Error: El archivo de imagen 40731.jpeg no existe.
# Error: El archivo de imagen 40732.jpeg no existe.
# Error: El archivo de imagen 40733.jpeg no existe.
# Error: El archivo de imagen 40735.jpeg no existe.
# Error: El archivo de imagen 40736.jpeg no existe.
# Error: El archivo de imagen 40737.jpeg no existe.
# Error: El archivo de imagen 40739.jpeg no existe.
# Error: El archivo de imagen 40740.jpeg no existe.
# Error: El archivo de imagen 40742.jpeg no existe.
# Error: El archivo de imagen 40745.jpeg no existe.
# Error: El archivo de imagen 40746.jpeg no existe.
# Error: El archivo de imagen 40750.jpeg no existe.
# Error: El archivo de imagen 40751.jpeg no existe.
# Error: El archivo de imagen 40753.jpeg no existe.
# Error: El archivo de imagen 40756.jpeg no existe.
# Error: El archivo de imagen 40762.jpeg no existe.
# Error: El archivo de imagen 40760.jpeg no existe.
# Error: El archivo de imagen 40764.jpeg no existe.
# Error: El archivo de imagen 40766.jpeg no existe.
# Error: El archivo de imagen 40767.jpeg no existe.
# Error: El archivo de imagen 40770.jpeg no existe.
# Error: El archivo de imagen 40772.jpeg no existe.
# Error: El archivo de imagen 40777.jpeg no existe.
# Error: El archivo de imagen 40780.jpeg no existe.
# Error: El archivo de imagen 40784.jpeg no existe.
# Error: El archivo de imagen 40787.jpeg no existe.
# Error: El archivo de imagen 40785.jpeg no existe.
# Error: El archivo de imagen 40790.jpeg no existe.
# Error: El archivo de imagen 40788.jpeg no existe.
# Error: El archivo de imagen 40789.jpeg no existe.
# Error: El archivo de imagen 40793.jpeg no existe.
# Error: El archivo de imagen 40792.jpeg no existe.
# Error: El archivo de imagen 40797.jpeg no existe.
# Error: El archivo de imagen 40798.jpeg no existe.
# Error: El archivo de imagen 40801.jpeg no existe.
# Error: El archivo de imagen 40803.jpeg no existe.
# Error: El archivo de imagen 40804.jpeg no existe.
# Error: El archivo de imagen 40805.jpeg no existe.
# Error: El archivo de imagen 40809.jpeg no existe.
# Error: El archivo de imagen 40812.jpeg no existe.
# Error: El archivo de imagen 40814.jpeg no existe.
# Error: El archivo de imagen 40819.jpeg no existe.
# Error: El archivo de imagen 40820.jpeg no existe.
# Error: El archivo de imagen 40821.jpeg no existe.
# Error: El archivo de imagen 40823.jpeg no existe.
# Error: El archivo de imagen 40825.jpeg no existe.
# Error: El archivo de imagen 40828.jpeg no existe.
# Error: El archivo de imagen 40829.jpeg no existe.
# Error: El archivo de imagen 40831.jpeg no existe.
# Error: El archivo de imagen 40832.jpeg no existe.
# Error: El archivo de imagen 40833.jpeg no existe.
# Error: El archivo de imagen 40834.jpeg no existe.
# Error: El archivo de imagen 40837.jpeg no existe.
# Error: El archivo de imagen 40841.jpeg no existe.
# Error: El archivo de imagen 40840.jpeg no existe.
# Error: El archivo de imagen 40844.jpeg no existe.
# Error: El archivo de imagen 40845.jpeg no existe.
# Error: El archivo de imagen 40846.jpeg no existe.
# Error: El archivo de imagen 40852.jpeg no existe.
# Error: El archivo de imagen 40851.jpeg no existe.
# Error: El archivo de imagen 40853.jpeg no existe.
# Error: El archivo de imagen 40855.jpeg no existe.
# Error: El archivo de imagen 40856.jpeg no existe.
# Error: El archivo de imagen 40858.jpeg no existe.
# Error: El archivo de imagen 40859.jpeg no existe.
# Error: El archivo de imagen 40860.jpeg no existe.
# Error: El archivo de imagen 40862.jpeg no existe.
# Error: El archivo de imagen 40861.jpeg no existe.
# Error: El archivo de imagen 40864.jpeg no existe.
# Error: El archivo de imagen 40868.jpeg no existe.
# Error: El archivo de imagen 40871.jpeg no existe.
# Error: El archivo de imagen 40874.jpeg no existe.
# Error: El archivo de imagen 40875.jpeg no existe.
# Error: El archivo de imagen 40880.jpeg no existe.
# Error: El archivo de imagen 40882.jpeg no existe.
# Error: El archivo de imagen 40883.jpeg no existe.
# Error: El archivo de imagen 40886.jpeg no existe.
# Error: El archivo de imagen 40887.jpeg no existe.
# Error: El archivo de imagen 40888.jpeg no existe.
# Error: El archivo de imagen 40890.jpeg no existe.
# Error: El archivo de imagen 40892.jpeg no existe.
# Error: El archivo de imagen 40895.jpeg no existe.
# Error: El archivo de imagen 40897.jpeg no existe.
# Error: El archivo de imagen 40899.jpeg no existe.
# Error: El archivo de imagen 40898.jpeg no existe.
# Error: El archivo de imagen 40901.jpeg no existe.
# Error: El archivo de imagen 40902.jpeg no existe.
# Error: El archivo de imagen 40903.jpeg no existe.
# Error: El archivo de imagen 40909.jpeg no existe.
# Error: El archivo de imagen 40912.jpeg no existe.
# Error: El archivo de imagen 40915.jpeg no existe.
# Error: El archivo de imagen 40920.jpeg no existe.
# Error: El archivo de imagen 40922.jpeg no existe.
# Error: El archivo de imagen 40923.jpeg no existe.
# Error: El archivo de imagen 40929.jpeg no existe.
# Error: El archivo de imagen 40927.jpeg no existe.
# Error: El archivo de imagen 40930.jpeg no existe.
# Error: El archivo de imagen 40931.jpeg no existe.
# Error: El archivo de imagen 40932.jpeg no existe.
# Error: El archivo de imagen 40933.jpeg no existe.
# Error: El archivo de imagen 40934.jpeg no existe.
# Error: El archivo de imagen 40935.jpeg no existe.
# Error: El archivo de imagen 40937.jpeg no existe.
# Error: El archivo de imagen 40939.jpeg no existe.
# Error: El archivo de imagen 40938.jpeg no existe.
# Error: El archivo de imagen 40942.jpeg no existe.
# Error: El archivo de imagen 40944.jpeg no existe.
# Error: El archivo de imagen 40945.jpeg no existe.
# Error: El archivo de imagen 40947.jpeg no existe.
# Error: El archivo de imagen 40950.jpeg no existe.
# Error: El archivo de imagen 40954.jpeg no existe.
# Error: El archivo de imagen 40953.jpeg no existe.
# Error: El archivo de imagen 40955.jpeg no existe.
# Error: El archivo de imagen 40959.jpeg no existe.
# Error: El archivo de imagen 40957.jpeg no existe.
# Error: El archivo de imagen 40960.jpeg no existe.
# Error: El archivo de imagen 40963.jpeg no existe.
# Error: El archivo de imagen 40967.jpeg no existe.
# Error: El archivo de imagen 40971.jpeg no existe.
# Error: El archivo de imagen 40972.jpeg no existe.
# Error: El archivo de imagen 40977.jpeg no existe.
# Error: El archivo de imagen 40979.jpeg no existe.
# Error: El archivo de imagen 40980.jpeg no existe.
# Error: El archivo de imagen 40983.jpeg no existe.
# Error: El archivo de imagen 40984.jpeg no existe.
# Error: El archivo de imagen 40985.jpeg no existe.
# Error: El archivo de imagen 40987.jpeg no existe.
# Error: El archivo de imagen 40990.jpeg no existe.
# Error: El archivo de imagen 40997.jpeg no existe.
# Error: El archivo de imagen 40999.jpeg no existe.
# Error: El archivo de imagen 41000.jpeg no existe.
# Error: El archivo de imagen 41004.jpeg no existe.
# Error: El archivo de imagen 41005.jpeg no existe.
# Error: El archivo de imagen 41006.jpeg no existe.
# Error: El archivo de imagen 41008.jpeg no existe.
# Error: El archivo de imagen 41009.jpeg no existe.
# Error: El archivo de imagen 41014.jpeg no existe.
# Error: El archivo de imagen 41012.jpeg no existe.
# Error: El archivo de imagen 41013.jpeg no existe.
# Error: El archivo de imagen 41016.jpeg no existe.
# Error: El archivo de imagen 41019.jpeg no existe.
# Error: El archivo de imagen 41021.jpeg no existe.
# Error: El archivo de imagen 41026.jpeg no existe.
# Error: El archivo de imagen 41022.jpeg no existe.
# Error: El archivo de imagen 41024.jpeg no existe.
# Error: El archivo de imagen 41027.jpeg no existe.
# Error: El archivo de imagen 41028.jpeg no existe.
# Error: El archivo de imagen 41030.jpeg no existe.
# Error: El archivo de imagen 41031.jpeg no existe.
# Error: El archivo de imagen 41032.jpeg no existe.
# Error: El archivo de imagen 41036.jpeg no existe.
# Error: El archivo de imagen 41041.jpeg no existe.
# Error: El archivo de imagen 41042.jpeg no existe.
# Error: El archivo de imagen 41044.jpeg no existe.
# Error: El archivo de imagen 41046.jpeg no existe.
# Error: El archivo de imagen 41050.jpeg no existe.
# Error: El archivo de imagen 41049.jpeg no existe.
# Error: El archivo de imagen 41053.jpeg no existe.
# Error: El archivo de imagen 41051.jpeg no existe.
# Error: El archivo de imagen 41052.jpeg no existe.
# Error: El archivo de imagen 41054.jpeg no existe.
# Error: El archivo de imagen 41058.jpeg no existe.
# Error: El archivo de imagen 41056.jpeg no existe.
# Error: El archivo de imagen 41060.jpeg no existe.
# Error: El archivo de imagen 41061.jpeg no existe.
# Error: El archivo de imagen 41062.jpeg no existe.
# Error: El archivo de imagen 41064.jpeg no existe.
# Error: El archivo de imagen 41066.jpeg no existe.
# Error: El archivo de imagen 41071.jpeg no existe.
# Error: El archivo de imagen 41070.jpeg no existe.
# Error: El archivo de imagen 41072.jpeg no existe.
# Error: El archivo de imagen 41075.jpeg no existe.
# Error: El archivo de imagen 41076.jpeg no existe.
# Error: El archivo de imagen 41074.jpeg no existe.
# Error: El archivo de imagen 41080.jpeg no existe.
# Error: El archivo de imagen 41081.jpeg no existe.
# Error: El archivo de imagen 41079.jpeg no existe.
# Error: El archivo de imagen 41084.jpeg no existe.
# Error: El archivo de imagen 41085.jpeg no existe.
# Error: El archivo de imagen 41087.jpeg no existe.
# Error: El archivo de imagen 41086.jpeg no existe.
# Error: El archivo de imagen 41089.jpeg no existe.
# Error: El archivo de imagen 41097.jpeg no existe.
# Error: El archivo de imagen 41098.jpeg no existe.
# Error: El archivo de imagen 41099.jpeg no existe.
# Error: El archivo de imagen 41101.jpeg no existe.
# Error: El archivo de imagen 41103.jpeg no existe.
# Error: El archivo de imagen 41102.jpeg no existe.
# Error: El archivo de imagen 41104.jpeg no existe.
# Error: El archivo de imagen 41107.jpeg no existe.
# Error: El archivo de imagen 41112.jpeg no existe.
# Error: El archivo de imagen 41118.jpeg no existe.
# Error: El archivo de imagen 41120.jpeg no existe.
# Error: El archivo de imagen 41127.jpeg no existe.
# Error: El archivo de imagen 41131.jpeg no existe.
# Error: El archivo de imagen 41138.jpeg no existe.
# Error: El archivo de imagen 41140.jpeg no existe.
# Error: El archivo de imagen 41142.jpeg no existe.
# Error: El archivo de imagen 41143.jpeg no existe.
# Error: El archivo de imagen 41144.jpeg no existe.
# Error: El archivo de imagen 41146.jpeg no existe.
# Error: El archivo de imagen 41149.jpeg no existe.
# Error: El archivo de imagen 41148.jpeg no existe.
# Error: El archivo de imagen 41153.jpeg no existe.
# Error: El archivo de imagen 41159.jpeg no existe.
# Error: El archivo de imagen 41158.jpeg no existe.
# Error: El archivo de imagen 41161.jpeg no existe.
# Error: El archivo de imagen 41162.jpeg no existe.
# Error: El archivo de imagen 41164.jpeg no existe.
# Error: El archivo de imagen 41169.jpeg no existe.
# Error: El archivo de imagen 41170.jpeg no existe.
# Error: El archivo de imagen 41171.jpeg no existe.
# Error: El archivo de imagen 41174.jpeg no existe.
# Error: El archivo de imagen 41177.jpeg no existe.
# Error: El archivo de imagen 41179.jpeg no existe.
# Error: El archivo de imagen 41181.jpeg no existe.
# Error: El archivo de imagen 41183.jpeg no existe.
# Error: El archivo de imagen 41184.jpeg no existe.
# Error: El archivo de imagen 41185.jpeg no existe.
# Error: El archivo de imagen 41187.jpeg no existe.
# Error: El archivo de imagen 41188.jpeg no existe.
# Error: El archivo de imagen 41190.jpeg no existe.
# Error: El archivo de imagen 41191.jpeg no existe.
# Error: El archivo de imagen 41193.jpeg no existe.
# Error: El archivo de imagen 41195.jpeg no existe.
# Error: El archivo de imagen 41196.jpeg no existe.
# Error: El archivo de imagen 41201.jpeg no existe.
# Error: El archivo de imagen 41202.jpeg no existe.
# Error: El archivo de imagen 41205.jpeg no existe.
# Error: El archivo de imagen 41203.jpeg no existe.
# Error: El archivo de imagen 41204.jpeg no existe.
# Error: El archivo de imagen 41207.jpeg no existe.
# Error: El archivo de imagen 41208.jpeg no existe.
# Error: El archivo de imagen 41213.jpeg no existe.
# Error: El archivo de imagen 41215.jpeg no existe.
# Error: El archivo de imagen 41212.jpeg no existe.
# Error: El archivo de imagen 41216.jpeg no existe.
# Error: El archivo de imagen 41217.jpeg no existe.
# Error: El archivo de imagen 41218.jpeg no existe.
# Error: El archivo de imagen 41219.jpeg no existe.
# Error: El archivo de imagen 41221.jpeg no existe.
# Error: El archivo de imagen 41222.jpeg no existe.
# Error: El archivo de imagen 41228.jpeg no existe.
# Error: El archivo de imagen 41229.jpeg no existe.
# Error: El archivo de imagen 41230.jpeg no existe.
# Error: El archivo de imagen 41233.jpeg no existe.
# Error: El archivo de imagen 41234.jpeg no existe.
# Error: El archivo de imagen 41235.jpeg no existe.
# Error: El archivo de imagen 41236.jpeg no existe.
# Error: El archivo de imagen 41237.jpeg no existe.
# Error: El archivo de imagen 41238.jpeg no existe.
# Error: El archivo de imagen 41242.jpeg no existe.
# Error: El archivo de imagen 41241.jpeg no existe.
# Error: El archivo de imagen 41248.jpeg no existe.
# Error: El archivo de imagen 41249.jpeg no existe.
# Error: El archivo de imagen 41254.jpeg no existe.
# Error: El archivo de imagen 41250.jpeg no existe.
# Error: El archivo de imagen 41255.jpeg no existe.
# Error: El archivo de imagen 41256.jpeg no existe.
# Error: El archivo de imagen 41257.jpeg no existe.
# Error: El archivo de imagen 41258.jpeg no existe.
# Error: El archivo de imagen 41263.jpeg no existe.
# Error: El archivo de imagen 41261.jpeg no existe.
# Error: El archivo de imagen 41265.jpeg no existe.
# Error: El archivo de imagen 41268.jpeg no existe.
# Error: El archivo de imagen 41273.jpeg no existe.
# Error: El archivo de imagen 41270.jpeg no existe.
# Error: El archivo de imagen 41272.jpeg no existe.
# Error: El archivo de imagen 41276.jpeg no existe.
# Error: El archivo de imagen 41283.jpeg no existe.
# Error: El archivo de imagen 41285.jpeg no existe.
# Error: El archivo de imagen 41287.jpeg no existe.
# Error: El archivo de imagen 41289.jpeg no existe.
# Error: El archivo de imagen 41288.jpeg no existe.
# Error: El archivo de imagen 41292.jpeg no existe.
# Error: El archivo de imagen 41295.jpeg no existe.
# Error: El archivo de imagen 41296.jpeg no existe.
# Error: El archivo de imagen 41301.jpeg no existe.
# Error: El archivo de imagen 41302.jpeg no existe.
# Error: El archivo de imagen 41303.jpeg no existe.
# Error: El archivo de imagen 41307.jpeg no existe.
# Error: El archivo de imagen 41309.jpeg no existe.
# Error: El archivo de imagen 41310.jpeg no existe.
# Error: El archivo de imagen 41314.jpeg no existe.
# Error: El archivo de imagen 41312.jpeg no existe.
# Error: El archivo de imagen 41317.jpeg no existe.
# Error: El archivo de imagen 41316.jpeg no existe.
# Error: El archivo de imagen 41319.jpeg no existe.
# Error: El archivo de imagen 41325.jpeg no existe.
# Error: El archivo de imagen 41328.jpeg no existe.
# Error: El archivo de imagen 41329.jpeg no existe.
# Error: El archivo de imagen 41332.jpeg no existe.
# Error: El archivo de imagen 41334.jpeg no existe.
# Error: El archivo de imagen 41336.jpeg no existe.
# Error: El archivo de imagen 41338.jpeg no existe.
# Error: El archivo de imagen 41340.jpeg no existe.
# Error: El archivo de imagen 41343.jpeg no existe.
# Error: El archivo de imagen 41342.jpeg no existe.
# Error: El archivo de imagen 41344.jpeg no existe.
# Error: El archivo de imagen 41349.jpeg no existe.
# Error: El archivo de imagen 41360.jpeg no existe.
# Error: El archivo de imagen 41361.jpeg no existe.
# Error: El archivo de imagen 41366.jpeg no existe.
# Error: El archivo de imagen 41368.jpeg no existe.
# Error: El archivo de imagen 41370.jpeg no existe.
# Error: El archivo de imagen 41371.jpeg no existe.
# Error: El archivo de imagen 41372.jpeg no existe.
# Error: El archivo de imagen 41374.jpeg no existe.
# Error: El archivo de imagen 41373.jpeg no existe.
# Error: El archivo de imagen 41376.jpeg no existe.
# Error: El archivo de imagen 41377.jpeg no existe.
# Error: El archivo de imagen 41378.jpeg no existe.
# Error: El archivo de imagen 41379.jpeg no existe.
# Error: El archivo de imagen 41380.jpeg no existe.
# Error: El archivo de imagen 41381.jpeg no existe.
# Error: El archivo de imagen 41384.jpeg no existe.
# Error: El archivo de imagen 41383.jpeg no existe.
# Error: El archivo de imagen 41387.jpeg no existe.
# Error: El archivo de imagen 41389.jpeg no existe.
# Error: El archivo de imagen 41390.jpeg no existe.
# Error: El archivo de imagen 41391.jpeg no existe.
# Error: El archivo de imagen 41394.jpeg no existe.
# Error: El archivo de imagen 41395.jpeg no existe.
# Error: El archivo de imagen 41397.jpeg no existe.
# Error: El archivo de imagen 41404.jpeg no existe.
# Error: El archivo de imagen 41405.jpeg no existe.
# Error: El archivo de imagen 41407.jpeg no existe.
# Error: El archivo de imagen 41411.jpeg no existe.
# Error: El archivo de imagen 41413.jpeg no existe.
# Error: El archivo de imagen 41415.jpeg no existe.
# Error: El archivo de imagen 41416.jpeg no existe.
# Error: El archivo de imagen 41419.jpeg no existe.
# Error: El archivo de imagen 41421.jpeg no existe.
# Error: El archivo de imagen 41423.jpeg no existe.
# Error: El archivo de imagen 41424.jpeg no existe.
# Error: El archivo de imagen 41425.jpeg no existe.
# Error: El archivo de imagen 41426.jpeg no existe.
# Error: El archivo de imagen 41427.jpeg no existe.
# Error: El archivo de imagen 41428.jpeg no existe.
# Error: El archivo de imagen 41429.jpeg no existe.
# Error: El archivo de imagen 41435.jpeg no existe.
# Error: El archivo de imagen 41436.jpeg no existe.
# Error: El archivo de imagen 41437.jpeg no existe.
# Error: El archivo de imagen 41441.jpeg no existe.
# Error: El archivo de imagen 41447.jpeg no existe.
# Error: El archivo de imagen 41445.jpeg no existe.
# Error: El archivo de imagen 41455.jpeg no existe.
# Error: El archivo de imagen 41456.jpeg no existe.
# Error: El archivo de imagen 41463.jpeg no existe.
# Error: El archivo de imagen 41464.jpeg no existe.
# Error: El archivo de imagen 41467.jpeg no existe.
# Error: El archivo de imagen 41473.jpeg no existe.
# Error: El archivo de imagen 41478.jpeg no existe.
# Error: El archivo de imagen 41475.jpeg no existe.
# Error: El archivo de imagen 41479.jpeg no existe.
# Error: El archivo de imagen 41480.jpeg no existe.
# Error: El archivo de imagen 41481.jpeg no existe.
# Error: El archivo de imagen 41483.jpeg no existe.
# Error: El archivo de imagen 41484.jpeg no existe.
# Error: El archivo de imagen 41488.jpeg no existe.
# Error: El archivo de imagen 41486.jpeg no existe.
# Error: El archivo de imagen 41487.jpeg no existe.
# Error: El archivo de imagen 41485.jpeg no existe.
# Error: El archivo de imagen 41489.jpeg no existe.
# Error: El archivo de imagen 41490.jpeg no existe.
# Error: El archivo de imagen 41494.jpeg no existe.
# Error: El archivo de imagen 41495.jpeg no existe.
# Error: El archivo de imagen 41498.jpeg no existe.
# Error: El archivo de imagen 41500.jpeg no existe.
# Error: El archivo de imagen 41503.jpeg no existe.
# Error: El archivo de imagen 41502.jpeg no existe.
# Error: El archivo de imagen 41508.jpeg no existe.
# Error: El archivo de imagen 41516.jpeg no existe.
# Error: El archivo de imagen 41521.jpeg no existe.
# Error: El archivo de imagen 41522.jpeg no existe.
# Error: El archivo de imagen 41524.jpeg no existe.
# Error: El archivo de imagen 41527.jpeg no existe.
# Error: El archivo de imagen 41526.jpeg no existe.
# Error: El archivo de imagen 41532.jpeg no existe.
# Error: El archivo de imagen 41534.jpeg no existe.
# Error: El archivo de imagen 41538.jpeg no existe.
# Error: El archivo de imagen 41540.jpeg no existe.
# Error: El archivo de imagen 41541.jpeg no existe.
# Error: El archivo de imagen 41542.jpeg no existe.
# Error: El archivo de imagen 41543.jpeg no existe.
# Error: El archivo de imagen 41544.jpeg no existe.
# Error: El archivo de imagen 41548.jpeg no existe.
# Error: El archivo de imagen 41549.jpeg no existe.
# Error: El archivo de imagen 41550.jpeg no existe.
# Error: El archivo de imagen 41553.jpeg no existe.
# Error: El archivo de imagen 41555.jpeg no existe.
# Error: El archivo de imagen 41554.jpeg no existe.
# Error: El archivo de imagen 41557.jpeg no existe.
# Error: El archivo de imagen 41556.jpeg no existe.
# Error: El archivo de imagen 41558.jpeg no existe.
# Error: El archivo de imagen 41562.jpeg no existe.
# Error: El archivo de imagen 41564.jpeg no existe.
# Error: El archivo de imagen 41566.jpeg no existe.
# Error: El archivo de imagen 41567.jpeg no existe.
# Error: El archivo de imagen 41569.jpeg no existe.
# Error: El archivo de imagen 41571.jpeg no existe.
# Error: El archivo de imagen 41573.jpeg no existe.
# Error: El archivo de imagen 41574.jpeg no existe.
# Error: El archivo de imagen 41575.jpeg no existe.
# Error: El archivo de imagen 41577.jpeg no existe.
# Error: El archivo de imagen 41578.jpeg no existe.
# Error: El archivo de imagen 41580.jpeg no existe.
# Error: El archivo de imagen 41588.jpeg no existe.
# Error: El archivo de imagen 41591.jpeg no existe.
# Error: El archivo de imagen 41592.jpeg no existe.
# Error: El archivo de imagen 41593.jpeg no existe.
# Error: El archivo de imagen 41594.jpeg no existe.
# Error: El archivo de imagen 41596.jpeg no existe.
# Error: El archivo de imagen 41598.jpeg no existe.
# Error: El archivo de imagen 41601.jpeg no existe.
# Error: El archivo de imagen 41602.jpeg no existe.
# Error: El archivo de imagen 41604.jpeg no existe.
# Error: El archivo de imagen 41605.jpeg no existe.
# Error: El archivo de imagen 41606.jpeg no existe.
# Error: El archivo de imagen 41607.jpeg no existe.
# Error: El archivo de imagen 41609.jpeg no existe.
# Error: El archivo de imagen 41610.jpeg no existe.
# Error: El archivo de imagen 41612.jpeg no existe.
# Error: El archivo de imagen 41617.jpeg no existe.
# Error: El archivo de imagen 41614.jpeg no existe.
# Error: El archivo de imagen 41613.jpeg no existe.
# Error: El archivo de imagen 41621.jpeg no existe.
# Error: El archivo de imagen 41622.jpeg no existe.
# Error: El archivo de imagen 41620.jpeg no existe.
# Error: El archivo de imagen 41624.jpeg no existe.
# Error: El archivo de imagen 41630.jpeg no existe.
# Error: El archivo de imagen 41632.jpeg no existe.
# Error: El archivo de imagen 41633.jpeg no existe.
# Error: El archivo de imagen 41636.jpeg no existe.
# Error: El archivo de imagen 41634.jpeg no existe.
# Error: El archivo de imagen 41640.jpeg no existe.
# Error: El archivo de imagen 41643.jpeg no existe.
# Error: El archivo de imagen 41641.jpeg no existe.
# Error: El archivo de imagen 41642.jpeg no existe.
# Error: El archivo de imagen 41647.jpeg no existe.
# Error: El archivo de imagen 41648.jpeg no existe.
# Error: El archivo de imagen 41652.jpeg no existe.
# Error: El archivo de imagen 41650.jpeg no existe.
# Error: El archivo de imagen 41653.jpeg no existe.
# Error: El archivo de imagen 41657.jpeg no existe.
# Error: El archivo de imagen 41662.jpeg no existe.
# Error: El archivo de imagen 41664.jpeg no existe.
# Error: El archivo de imagen 41666.jpeg no existe.
# Error: El archivo de imagen 41669.jpeg no existe.
# Error: El archivo de imagen 41673.jpeg no existe.
# Error: El archivo de imagen 41676.jpeg no existe.
# Error: El archivo de imagen 41679.jpeg no existe.
# Error: El archivo de imagen 41683.jpeg no existe.
# Error: El archivo de imagen 41684.jpeg no existe.
# Error: El archivo de imagen 41686.jpeg no existe.
# Error: El archivo de imagen 41687.jpeg no existe.
# Error: El archivo de imagen 41690.jpeg no existe.
# Error: El archivo de imagen 41695.jpeg no existe.
# Error: El archivo de imagen 41696.jpeg no existe.
# Error: El archivo de imagen 41698.jpeg no existe.
# Error: El archivo de imagen 41700.jpeg no existe.
# Error: El archivo de imagen 41705.jpeg no existe.
# Error: El archivo de imagen 41706.jpeg no existe.
# Error: El archivo de imagen 41711.jpeg no existe.
# Error: El archivo de imagen 41709.jpeg no existe.
# Error: El archivo de imagen 41712.jpeg no existe.
# Error: El archivo de imagen 41713.jpeg no existe.
# Error: El archivo de imagen 41714.jpeg no existe.
# Error: El archivo de imagen 41716.jpeg no existe.
# Error: El archivo de imagen 41718.jpeg no existe.
# Error: El archivo de imagen 41717.jpeg no existe.
# Error: El archivo de imagen 41719.jpeg no existe.
# Error: El archivo de imagen 41722.jpeg no existe.
# Error: El archivo de imagen 41724.jpeg no existe.
# Error: El archivo de imagen 41725.jpeg no existe.
# Error: El archivo de imagen 41726.jpeg no existe.
# Error: El archivo de imagen 41730.jpeg no existe.
# Error: El archivo de imagen 41732.jpeg no existe.
# Error: El archivo de imagen 41737.jpeg no existe.
# Error: El archivo de imagen 41740.jpeg no existe.
# Error: El archivo de imagen 41743.jpeg no existe.
# Error: El archivo de imagen 41747.jpeg no existe.
# Error: El archivo de imagen 41750.jpeg no existe.
# Error: El archivo de imagen 41754.jpeg no existe.
# Error: El archivo de imagen 41753.jpeg no existe.
# Error: El archivo de imagen 41756.jpeg no existe.
# Error: El archivo de imagen 41759.jpeg no existe.
# Error: El archivo de imagen 41760.jpeg no existe.
# Error: El archivo de imagen 41758.jpeg no existe.
# Error: El archivo de imagen 41765.jpeg no existe.
# Error: El archivo de imagen 41766.jpeg no existe.
# Error: El archivo de imagen 41769.jpeg no existe.
# Error: El archivo de imagen 41770.jpeg no existe.
# Error: El archivo de imagen 41771.jpeg no existe.
# Error: El archivo de imagen 41774.jpeg no existe.
# Error: El archivo de imagen 41775.jpeg no existe.
# Error: El archivo de imagen 41779.jpeg no existe.
# Error: El archivo de imagen 41782.jpeg no existe.
# Error: El archivo de imagen 41780.jpeg no existe.
# Error: El archivo de imagen 41783.jpeg no existe.
# Error: El archivo de imagen 41788.jpeg no existe.
# ...
# Error: El archivo de imagen 49382.jpeg no existe.
# Error: El archivo de imagen 49380.jpeg no existe.
# Error: El archivo de imagen 49387.jpeg no existe.
# Error: El archivo de imagen 49385.jpeg no existe.
# Error: El archivo de imagen 49389.jpeg no existe.
# Error: El archivo de imagen 49390.jpeg no existe.
# Error: El archivo de imagen 49392.jpeg no existe.
# Error: El archivo de imagen 49394.jpeg no existe.
# Error: El archivo de imagen 49395.jpeg no existe.
# Error: El archivo de imagen 49396.jpeg no existe.
# Error: El archivo de imagen 49401.jpeg no existe.
# Error: El archivo de imagen 49399.jpeg no existe.
# Error: El archivo de imagen 49402.jpeg no existe.
# Error: El archivo de imagen 49405.jpeg no existe.
# Error: El archivo de imagen 49407.jpeg no existe.
# Error: El archivo de imagen 49412.jpeg no existe.
# Error: El archivo de imagen 49418.jpeg no existe.
# Error: El archivo de imagen 49419.jpeg no existe.
# Error: El archivo de imagen 49423.jpeg no existe.
# Error: El archivo de imagen 49421.jpeg no existe.
# Error: El archivo de imagen 49425.jpeg no existe.
# Error: El archivo de imagen 49431.jpeg no existe.
# Error: El archivo de imagen 49429.jpeg no existe.
# Error: El archivo de imagen 49432.jpeg no existe.
# Error: El archivo de imagen 49433.jpeg no existe.
# Error: El archivo de imagen 49435.jpeg no existe.
# Error: El archivo de imagen 49438.jpeg no existe.
# Error: El archivo de imagen 49439.jpeg no existe.
# Error: El archivo de imagen 49440.jpeg no existe.
# Error: El archivo de imagen 49444.jpeg no existe.
# Error: El archivo de imagen 49442.jpeg no existe.
# Error: El archivo de imagen 49447.jpeg no existe.
# Error: El archivo de imagen 49446.jpeg no existe.
# Error: El archivo de imagen 49445.jpeg no existe.
# Error: El archivo de imagen 49448.jpeg no existe.
# Error: El archivo de imagen 49455.jpeg no existe.
# Error: El archivo de imagen 49458.jpeg no existe.
# Error: El archivo de imagen 49459.jpeg no existe.
# Error: El archivo de imagen 49464.jpeg no existe.
# Error: El archivo de imagen 49465.jpeg no existe.
# Error: El archivo de imagen 49468.jpeg no existe.
# Error: El archivo de imagen 49471.jpeg no existe.
# Error: El archivo de imagen 49474.jpeg no existe.
# Error: El archivo de imagen 49472.jpeg no existe.
# Error: El archivo de imagen 49475.jpeg no existe.
# Error: El archivo de imagen 49477.jpeg no existe.
# Error: El archivo de imagen 49478.jpeg no existe.
# Error: El archivo de imagen 49480.jpeg no existe.
# Error: El archivo de imagen 49484.jpeg no existe.
# Error: El archivo de imagen 49483.jpeg no existe.
# Error: El archivo de imagen 49486.jpeg no existe.
# Error: El archivo de imagen 49491.jpeg no existe.
# Error: El archivo de imagen 49493.jpeg no existe.
# Error: El archivo de imagen 49495.jpeg no existe.
# Error: El archivo de imagen 49496.jpeg no existe.
# Error: El archivo de imagen 49494.jpeg no existe.
# Error: El archivo de imagen 49497.jpeg no existe.
# Error: El archivo de imagen 49500.jpeg no existe.
# Error: El archivo de imagen 49502.jpeg no existe.
# Error: El archivo de imagen 49501.jpeg no existe.
# Error: El archivo de imagen 49503.jpeg no existe.
# Error: El archivo de imagen 49505.jpeg no existe.
# Error: El archivo de imagen 49507.jpeg no existe.
# Error: El archivo de imagen 49508.jpeg no existe.
# Error: El archivo de imagen 49515.jpeg no existe.
# Error: El archivo de imagen 49514.jpeg no existe.
# Error: El archivo de imagen 49516.jpeg no existe.
# Error: El archivo de imagen 49521.jpeg no existe.
# Error: El archivo de imagen 49524.jpeg no existe.
# Error: El archivo de imagen 49523.jpeg no existe.
# Error: El archivo de imagen 49525.jpeg no existe.
# Error: El archivo de imagen 49526.jpeg no existe.
# Error: El archivo de imagen 49528.jpeg no existe.
# Error: El archivo de imagen 49532.jpeg no existe.
# Error: El archivo de imagen 49534.jpeg no existe.
# Error: El archivo de imagen 49533.jpeg no existe.
# Error: El archivo de imagen 49535.jpeg no existe.
# Error: El archivo de imagen 49538.jpeg no existe.
# Error: El archivo de imagen 49537.jpeg no existe.
# Error: El archivo de imagen 49542.jpeg no existe.
# Error: El archivo de imagen 49545.jpeg no existe.
# Error: El archivo de imagen 49546.jpeg no existe.
# Error: El archivo de imagen 49548.jpeg no existe.
# Error: El archivo de imagen 49549.jpeg no existe.
# Error: El archivo de imagen 49550.jpeg no existe.
# Error: El archivo de imagen 49553.jpeg no existe.
# Error: El archivo de imagen 49554.jpeg no existe.
# Error: El archivo de imagen 49555.jpeg no existe.
# Error: El archivo de imagen 49566.jpeg no existe.
# Error: El archivo de imagen 49563.jpeg no existe.
# Error: El archivo de imagen 49562.jpeg no existe.
# Error: El archivo de imagen 49568.jpeg no existe.
# Error: El archivo de imagen 49570.jpeg no existe.
# Error: El archivo de imagen 49564.jpeg no existe.
# Error: El archivo de imagen 49567.jpeg no existe.
# Error: El archivo de imagen 49571.jpeg no existe.
# Error: El archivo de imagen 49565.jpeg no existe.
# Error: El archivo de imagen 49573.jpeg no existe.
# Error: El archivo de imagen 49574.jpeg no existe.
# Error: El archivo de imagen 49576.jpeg no existe.
# Error: El archivo de imagen 49580.jpeg no existe.
# Error: El archivo de imagen 49582.jpeg no existe.
# Error: El archivo de imagen 49584.jpeg no existe.
# Error: El archivo de imagen 49586.jpeg no existe.
# Error: El archivo de imagen 49588.jpeg no existe.
# Error: El archivo de imagen 49590.jpeg no existe.
# Error: El archivo de imagen 49592.jpeg no existe.
# Error: El archivo de imagen 49596.jpeg no existe.
# Error: El archivo de imagen 49597.jpeg no existe.
# Error: El archivo de imagen 49599.jpeg no existe.
# Error: El archivo de imagen 49601.jpeg no existe.
# Error: El archivo de imagen 49602.jpeg no existe.
# Error: El archivo de imagen 49604.jpeg no existe.
# Error: El archivo de imagen 49608.jpeg no existe.
# Error: El archivo de imagen 49609.jpeg no existe.
# Error: El archivo de imagen 49611.jpeg no existe.
# Error: El archivo de imagen 49612.jpeg no existe.
# Error: El archivo de imagen 49613.jpeg no existe.
# Error: El archivo de imagen 49616.jpeg no existe.
# Error: El archivo de imagen 49619.jpeg no existe.
# Error: El archivo de imagen 49623.jpeg no existe.
# Error: El archivo de imagen 49624.jpeg no existe.
# Error: El archivo de imagen 49630.jpeg no existe.
# Error: El archivo de imagen 49632.jpeg no existe.
# Error: El archivo de imagen 49634.jpeg no existe.
# Error: El archivo de imagen 49635.jpeg no existe.
# Error: El archivo de imagen 49638.jpeg no existe.
# Error: El archivo de imagen 49637.jpeg no existe.
# Error: El archivo de imagen 49643.jpeg no existe.
# Error: El archivo de imagen 49650.jpeg no existe.
# Error: El archivo de imagen 49652.jpeg no existe.
# Error: El archivo de imagen 49661.jpeg no existe.
# Error: El archivo de imagen 49662.jpeg no existe.
# Error: El archivo de imagen 49664.jpeg no existe.
# Error: El archivo de imagen 49665.jpeg no existe.
# Error: El archivo de imagen 49667.jpeg no existe.
# Error: El archivo de imagen 49670.jpeg no existe.
# Error: El archivo de imagen 49672.jpeg no existe.
# Error: El archivo de imagen 49673.jpeg no existe.
# Error: El archivo de imagen 49675.jpeg no existe.
# Error: El archivo de imagen 49676.jpeg no existe.
# Error: El archivo de imagen 49677.jpeg no existe.
# Error: El archivo de imagen 49681.jpeg no existe.
# Error: El archivo de imagen 49679.jpeg no existe.
# Error: El archivo de imagen 49684.jpeg no existe.
# Error: El archivo de imagen 49687.jpeg no existe.
# Error: El archivo de imagen 49685.jpeg no existe.
# Error: El archivo de imagen 49688.jpeg no existe.
# Error: El archivo de imagen 49690.jpeg no existe.
# Error: El archivo de imagen 49691.jpeg no existe.
# Error: El archivo de imagen 49693.jpeg no existe.
# Error: El archivo de imagen 49697.jpeg no existe.
# Error: El archivo de imagen 49698.jpeg no existe.
# Error: El archivo de imagen 49700.jpeg no existe.
# Error: El archivo de imagen 49699.jpeg no existe.
# Error: El archivo de imagen 49704.jpeg no existe.
# Error: El archivo de imagen 49706.jpeg no existe.
# Error: El archivo de imagen 49705.jpeg no existe.
# Error: El archivo de imagen 49708.jpeg no existe.
# Error: El archivo de imagen 49709.jpeg no existe.
# Error: El archivo de imagen 49712.jpeg no existe.
# Error: El archivo de imagen 49711.jpeg no existe.
# Error: El archivo de imagen 49713.jpeg no existe.
# Error: El archivo de imagen 49716.jpeg no existe.
# Error: El archivo de imagen 49720.jpeg no existe.
# Error: El archivo de imagen 49719.jpeg no existe.
# Error: El archivo de imagen 49722.jpeg no existe.
# Error: El archivo de imagen 49721.jpeg no existe.
# Error: El archivo de imagen 49723.jpeg no existe.
# Error: El archivo de imagen 49725.jpeg no existe.
# Error: El archivo de imagen 49727.jpeg no existe.
# Error: El archivo de imagen 49730.jpeg no existe.
# Error: El archivo de imagen 49729.jpeg no existe.
# Error: El archivo de imagen 49733.jpeg no existe.
# Error: El archivo de imagen 49735.jpeg no existe.
# Error: El archivo de imagen 49741.jpeg no existe.
# Error: El archivo de imagen 49738.jpeg no existe.
# Error: El archivo de imagen 49739.jpeg no existe.
# Error: El archivo de imagen 49743.jpeg no existe.
# Error: El archivo de imagen 49744.jpeg no existe.
# Error: El archivo de imagen 49748.jpeg no existe.
# Error: El archivo de imagen 49751.jpeg no existe.
# Error: El archivo de imagen 49752.jpeg no existe.
# Error: El archivo de imagen 49754.jpeg no existe.
# Error: El archivo de imagen 49755.jpeg no existe.
# Error: El archivo de imagen 49759.jpeg no existe.
# Error: El archivo de imagen 49762.jpeg no existe.
# Error: El archivo de imagen 49764.jpeg no existe.
# Error: El archivo de imagen 49765.jpeg no existe.
# Error: El archivo de imagen 49767.jpeg no existe.
# Error: El archivo de imagen 49768.jpeg no existe.
# Error: El archivo de imagen 49774.jpeg no existe.
# Error: El archivo de imagen 49770.jpeg no existe.
# Error: El archivo de imagen 49769.jpeg no existe.
# Error: El archivo de imagen 49775.jpeg no existe.
# Error: El archivo de imagen 49771.jpeg no existe.
# Error: El archivo de imagen 49773.jpeg no existe.
# Error: El archivo de imagen 49782.jpeg no existe.
# Error: El archivo de imagen 49777.jpeg no existe.
# Error: El archivo de imagen 49787.jpeg no existe.
# Error: El archivo de imagen 49788.jpeg no existe.
# Error: El archivo de imagen 49791.jpeg no existe.
# Error: El archivo de imagen 49790.jpeg no existe.
# Error: El archivo de imagen 49798.jpeg no existe.
# Error: El archivo de imagen 49796.jpeg no existe.
# Error: El archivo de imagen 49795.jpeg no existe.
# Error: El archivo de imagen 49797.jpeg no existe.
# Error: El archivo de imagen 49800.jpeg no existe.
# Error: El archivo de imagen 49805.jpeg no existe.
# Error: El archivo de imagen 49806.jpeg no existe.
# Error: El archivo de imagen 49807.jpeg no existe.
# Error: El archivo de imagen 49808.jpeg no existe.
# Error: El archivo de imagen 49811.jpeg no existe.
# Error: El archivo de imagen 49812.jpeg no existe.
# Error: El archivo de imagen 49814.jpeg no existe.
# Error: El archivo de imagen 49815.jpeg no existe.
# Error: El archivo de imagen 49816.jpeg no existe.
# Error: El archivo de imagen 49818.jpeg no existe.
# Error: El archivo de imagen 49817.jpeg no existe.
# Error: El archivo de imagen 49820.jpeg no existe.
# Error: El archivo de imagen 49825.jpeg no existe.
# Error: El archivo de imagen 49829.jpeg no existe.
# Error: El archivo de imagen 49830.jpeg no existe.
# Error: El archivo de imagen 49831.jpeg no existe.
# Error: El archivo de imagen 49832.jpeg no existe.
# Error: El archivo de imagen 49834.jpeg no existe.
# Error: El archivo de imagen 49836.jpeg no existe.
# Error: El archivo de imagen 49838.jpeg no existe.
# Error: El archivo de imagen 49841.jpeg no existe.
# Error: El archivo de imagen 49846.jpeg no existe.
# Error: El archivo de imagen 49848.jpeg no existe.
# Error: El archivo de imagen 49851.jpeg no existe.
# Error: El archivo de imagen 49854.jpeg no existe.
# Error: El archivo de imagen 49855.jpeg no existe.
# Error: El archivo de imagen 49858.jpeg no existe.
# Error: El archivo de imagen 49862.jpeg no existe.
# Error: El archivo de imagen 49860.jpeg no existe.
# Error: El archivo de imagen 49863.jpeg no existe.
# Error: El archivo de imagen 49865.jpeg no existe.
# Error: El archivo de imagen 49864.jpeg no existe.
# Error: El archivo de imagen 49870.jpeg no existe.
# Error: El archivo de imagen 49871.jpeg no existe.
# Error: El archivo de imagen 49874.jpeg no existe.
# Error: El archivo de imagen 49878.jpeg no existe.
# Error: El archivo de imagen 49877.jpeg no existe.
# Error: El archivo de imagen 49883.jpeg no existe.
# Error: El archivo de imagen 49884.jpeg no existe.
# Error: El archivo de imagen 49885.jpeg no existe.
# Error: El archivo de imagen 49887.jpeg no existe.
# Error: El archivo de imagen 49888.jpeg no existe.
# Error: El archivo de imagen 49889.jpeg no existe.
# Error: El archivo de imagen 49890.jpeg no existe.
# Error: El archivo de imagen 49891.jpeg no existe.
# Error: El archivo de imagen 49892.jpeg no existe.
# Error: El archivo de imagen 49894.jpeg no existe.
# Error: El archivo de imagen 49895.jpeg no existe.
# Error: El archivo de imagen 49899.jpeg no existe.
# Error: El archivo de imagen 49896.jpeg no existe.
# Error: El archivo de imagen 49900.jpeg no existe.
# Error: El archivo de imagen 49906.jpeg no existe.
# Error: El archivo de imagen 49907.jpeg no existe.
# Error: El archivo de imagen 49908.jpeg no existe.
# Error: El archivo de imagen 49910.jpeg no existe.
# Error: El archivo de imagen 49916.jpeg no existe.
# Error: El archivo de imagen 49914.jpeg no existe.
# Error: El archivo de imagen 49919.jpeg no existe.
# Error: El archivo de imagen 49920.jpeg no existe.
# Error: El archivo de imagen 49921.jpeg no existe.
# Error: El archivo de imagen 49922.jpeg no existe.
# Error: El archivo de imagen 49924.jpeg no existe.
# Error: El archivo de imagen 49928.jpeg no existe.
# Error: El archivo de imagen 49931.jpeg no existe.
# Error: El archivo de imagen 49933.jpeg no existe.
# Error: El archivo de imagen 49934.jpeg no existe.
# Error: El archivo de imagen 49938.jpeg no existe.
# Error: El archivo de imagen 49941.jpeg no existe.
# Error: El archivo de imagen 49942.jpeg no existe.
# Error: El archivo de imagen 49943.jpeg no existe.
# Error: El archivo de imagen 49945.jpeg no existe.
# Error: El archivo de imagen 49946.jpeg no existe.
# Error: El archivo de imagen 49948.jpeg no existe.
# Error: El archivo de imagen 49952.jpeg no existe.
# Error: El archivo de imagen 49951.jpeg no existe.
# Error: El archivo de imagen 49953.jpeg no existe.
# Error: El archivo de imagen 49954.jpeg no existe.
# Error: El archivo de imagen 49955.jpeg no existe.
# Error: El archivo de imagen 49956.jpeg no existe.
# Error: El archivo de imagen 49958.jpeg no existe.
# Error: El archivo de imagen 49957.jpeg no existe.
# Error: El archivo de imagen 49960.jpeg no existe.
# Error: El archivo de imagen 49963.jpeg no existe.
# Error: El archivo de imagen 49965.jpeg no existe.
# Error: El archivo de imagen 49966.jpeg no existe.
# Error: El archivo de imagen 49967.jpeg no existe.
# Error: El archivo de imagen 49972.jpeg no existe.
# Error: El archivo de imagen 49973.jpeg no existe.
# Error: El archivo de imagen 49976.jpeg no existe.
# Error: El archivo de imagen 49978.jpeg no existe.
# Error: El archivo de imagen 49981.jpeg no existe.
# Error: El archivo de imagen 49984.jpeg no existe.
# Error: El archivo de imagen 49988.jpeg no existe.
# Error: El archivo de imagen 49989.jpeg no existe.
# Error: El archivo de imagen 49990.jpeg no existe.
# Error: El archivo de imagen 49991.jpeg no existe.
# Error: El archivo de imagen 49994.jpeg no existe.
# Error: El archivo de imagen 49993.jpeg no existe.
# Error: El archivo de imagen 49996.jpeg no existe.
# Error: El archivo de imagen 49997.jpeg no existe.
# Error: El archivo de imagen 49999.jpeg no existe.
# Error: El archivo de imagen 49998.jpeg no existe.
# Error: El archivo de imagen 50001.jpeg no existe.
# Error: El archivo de imagen 50003.jpeg no existe.
# Error: El archivo de imagen 50004.jpeg no existe.
# Error: El archivo de imagen 50010.jpeg no existe.
# Error: El archivo de imagen 50012.jpeg no existe.
# Error: El archivo de imagen 50011.jpeg no existe.
# Error: El archivo de imagen 50014.jpeg no existe.
# Error: El archivo de imagen 50015.jpeg no existe.
# Error: El archivo de imagen 50017.jpeg no existe.
# 25099
# 20079 Training Items, 5020 Validation Items

# %% [markdown]
# #ENTRENAMIENTO

# %%
# Definimos el modelo y el optimizador
LR = 2e-4
epochs = 50
batch_size = 32
B = [0.5,0.999]
mlp_model = MLP_Model("MLP MODEL", vocab_size=260, embedding_dim=4, num_classes=4).to(device)
opt = torch.optim.Adam(mlp_model.parameters(), lr=LR,betas=B)
crit = nn.CrossEntropyLoss()

# %%
train_model(mlp_model, train_loader, val_loader, crit, opt, epochs, 4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/50 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='628' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/628 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c4a0982d054f> in <cell line: 1>()
# ----> 1 train_model(mlp_model, train_loader, val_loader, crit, opt, epochs, 4)
#
# <ipython-input-7-30f8e768413c> in train_model(mlp_model, train_loader, valid_loader, criterion, optim, number_epochs, numberOfClass)
#      10   for epoch in mb:
#      11       start_time = time.time()
# ---> 12       train_loss = train_epoch(mlp_model, train_loader, criterion, optim,mb,numberOfClass)
#      13       train_history.append(train_loss)
#      14       print("Training epoch {} | Loss {:.6f} | Time {:.2f} seconds"
#
# <ipython-input-5-c28ee3fd3d11> in train_epoch(mlp_model, loader, criterion, optim, mb, numberOfClass)
#      18     for img, tabulars, label in  progress_bar(loader,parent = mb):
#      19       batch_size = img.size(0)
# ---> 20       epoch_loss_accumulated += train_step(mlp_model,criterion,optim, img, tabulars, label, batch_size,numberOfClass)
#      21     return epoch_loss_accumulated/len(loader)
#
# <ipython-input-5-c28ee3fd3d11> in train_step(mlp_model, criterion, optim, img, tabulars, label, batch_size, numberOfClass)
#       7 def train_step(mlp_model, criterion, optim, img,tabulars, label, batch_size, numberOfClass):
#       8     optim.zero_grad()
# ----> 9     output = mlp_model(input, tabulars)
#      10     loss = criterion(output, label)
#      11     loss.backward()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-19-90a6eeee3dbc> in forward(self, x, tabulars)
#      22     # entrada de 256*192
#      23     emb_Location = self.embedding(tabulars[4])
# ---> 24     x = x.view(x.size(0), 1, 28, 28)
#      25     x = F.relu(self.bn1(self.conv1(x)))
#      26     x = F.relu(self.bn2(self.conv2(x)))
#
# AttributeError: 'function' object has no attribute 'view'

# %%
# Guardado del modelo

torch.save(mlp_model.state_dict(),mlp_model.name+".dat")

# %%
# %tensorboard --logdir=runs/

# %% [markdown]
# #Weights and Biases IMPLEMENTACION

# %%
def train_model_2():
  
  train_loader, val_loader, num_classes = get_dataloaders(train_transform,config.batch_size)
  mlp_model = MLP_Model("MLP MODEL", vocab_size=200, embedding_dim=4, num_classes=4).to(device)
  opt = torch.optim.Adam(mlp_model.parameters(), lr=config.LR,betas=config.B)
  crit = nn.CrossEntropyLoss()
  
  train_history = []
  valid_history = []
  accuracy_history = []
  now = datetime.datetime.now()
  date_time = now.strftime("%m%d%Y_%H%M%S")
  name = 'runs/'+mlp_model.name+'_'+date_time
  tensorBoard_writer = SummaryWriter(name) 
  mb = master_bar(range(1, config.epochs+1))
  for epoch in mb:
      start_time = time.time()     
      train_loss = train_epoch(mlp_model, train_loader, crit, opt,mb,num_classes)
      train_history.append(train_loss)
      print("Training epoch {} | Loss {:.6f} | Time {:.2f} seconds"
            .format(epoch + 1, train_loss, time.time() - start_time))
      
      start_time = time.time()
      val_loss, acc = validation_epoch(mlp_model, val_loader, crit)
      valid_history.append(val_loss)
      accuracy_history.append(acc)
      print("Validation epoch {} | Loss {:.6f} | Accuracy {:.2f}% | Time {:.2f} seconds"
            .format(epoch + 1, val_loss, acc, time.time() - start_time))
      # Se carga en tensorBoard #Loss #Validation en train y val
      tensorBoard_writer.add_scalar(tag="Train Loss", scalar_value=train_loss, global_step=epoch)
      tensorBoard_writer.add_scalar(tag="Validation Loss", scalar_value=val_loss, global_step=epoch)
      tensorBoard_writer.add_scalar(tag="Validation Accuracy", scalar_value=acc, global_step=epoch)
  tensorBoard_writer.close()

# %%
sweep_configuration = {
    'method': 'grid',         # 'grid', 'hyperopt', 'bayesian'
    'metric': {
        'name': 'acc',     # 'accuracy'
        'goal': 'maximize'      # 'maximize'
    },
    'parameters': {
        'batch_size': {'values': [32]},
        'epochs': {'values': [5,10,20,50,100]},
        'B': {'values': [[0.5,0.999]]},
        'learning_rate': {'values': [0.0002, 0.0004, 0.0006, 0.0010, 0.010, 0.1]}
     }
}

# %%
sweep_id = wandb.sweep(sweep_configuration, project="MLP-Obligatorio", entity="vainilla")
wandb.agent(sweep_id, function=train_model_2, count=15, project='MLP-Obligatorio')
